# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    city_weather = requests.get(city_url).json()
        # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_weatherdescription = city_weather["weather"][0]["description"] 
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_weatherdescription,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | talnakh
# Processing Record 3 of Set 1 | isangel
# Processing Record 4 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 1 | filadelfia
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | florianopolis
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | kurchum
# Processing Record 10 of Set 1 | te anau
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | samarai
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | grindavik
# Processing Record 21 of Set 1 | adrar
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | fortuna
# Processing Record 25 of Set 1 | soto la marina
# Processing Record 26 of Set 1 | khatanga
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | yorosso
# Processing Record 31 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | komsomolskiy
# Processing Record 34 of Set 1 | sawakin
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | sakakah
# Processing Record 37 of Set 1 | kamaishi
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | santa luzia
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | pisco
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | madimba
# Processing Record 48 of Set 1 | chumikan
# Processing Record 49 of Set 1 | pangoa
# Processing Record 50 of Set 1 | laguna
# Processing Record 1 of Set 2 | riyadh
# Processing Record 2 of Set 2 | montepuez
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | basco
# Processing Record 10 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 2 | guayaramerin
# Processing Record 12 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 2 | sindor
# Processing Record 14 of Set 2 | ixtapa
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | jaciara
# Processing Record 18 of Set 2 | port macquarie
# Processing Record 19 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | dubti
# Processing Record 24 of Set 2 | caborca
# Processing Record 25 of Set 2 | souillac
# Processing Record 26 of Set 2 | sao filipe
# Processing Record 27 of Set 2 | kaeo
# Processing Record 28 of Set 2 | tocopilla
# Processing Record 29 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 2 | tobias barreto
# Processing Record 31 of Set 2 | jeremie
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | mizdah
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | holovyne
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | rikitea
# Processing Record 39 of Set 2 | tiksi
# Processing Record 40 of Set 2 | kyshtovka
# Processing Record 41 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | salisbury
# Processing Record 45 of Set 2 | rudnya
# Processing Record 46 of Set 2 | chabahar
# Processing Record 47 of Set 2 | juruti
# Processing Record 48 of Set 2 | vilhena
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | jacobina
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | vicksburg
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | monaghan
# Processing Record 6 of Set 3 | northam
# Processing Record 7 of Set 3 | mitsamiouli
# Processing Record 8 of Set 3 | forbes
# Processing Record 9 of Set 3 | leningradskiy
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | zhigansk
# Processing Record 12 of Set 3 | manaure
# Processing Record 13 of Set 3 | ewa beach
# Processing Record 14 of Set 3 | huarmey
# Processing Record 15 of Set 3 | ampanihy
# Processing Record 16 of Set 3 | clyde river
# Processing Record 17 of Set 3 | piacabucu
# Processing Record 18 of Set 3 | stryn
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | yulara
# Processing Record 22 of Set 3 | saint-pierre
# Processing Record 23 of Set 3 | geraldton
# Processing Record 24 of Set 3 | la fleche
# Processing Record 25 of Set 3 | ugoofaaru
# Processing Record 26 of Set 3 | esperance
# Processing Record 27 of Set 3 | kavieng
# Processing Record 28 of Set 3 | volchansk
# Processing Record 29 of Set 3 | vostok
# Processing Record 30 of Set 3 | broken hill
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | jinxiang
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | port-gentil
# Processing Record 38 of Set 3 | san juan
# Processing Record 39 of Set 3 | kilindoni
# Processing Record 40 of Set 3 | lorengau
# Processing Record 41 of Set 3 | shaping
# Processing Record 42 of Set 3 | ashcroft
# Processing Record 43 of Set 3 | sao miguel do araguaia
# Processing Record 44 of Set 3 | kijang
# Processing Record 45 of Set 3 | salalah
# Processing Record 46 of Set 3 | hithadhoo
# Processing Record 47 of Set 3 | vanavara
# Processing Record 48 of Set 3 | vestmannaeyjar
# Processing Record 49 of Set 3 | coahuayana
# Processing Record 50 of Set 3 | shingu
# Processing Record 1 of Set 4 | minbu
# Processing Record 2 of Set 4 | port lincoln
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | pangnirtung
# Processing Record 5 of Set 4 | namibe
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | phonhong
# Processing Record 8 of Set 4 | sokoto
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | kingman
# Processing Record 11 of Set 4 | mayo
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | ust-koksa
# Processing Record 14 of Set 4 | fukue
# Processing Record 15 of Set 4 | touros
# Processing Record 16 of Set 4 | kalmar
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | nelson bay
# Processing Record 19 of Set 4 | fairbanks
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | jalingo
# Processing Record 22 of Set 4 | abu kamal
# Processing Record 23 of Set 4 | sovetskaya gavan
# Processing Record 24 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 4 | bengkulu
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | aklavik
# Processing Record 28 of Set 4 | verkhnyaya inta
# Processing Record 29 of Set 4 | bereda
# Processing Record 30 of Set 4 | porto santo
# Processing Record 31 of Set 4 | haines junction
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | sorland
# Processing Record 34 of Set 4 | axim
# Processing Record 35 of Set 4 | watertown
# Processing Record 36 of Set 4 | gat
# Processing Record 37 of Set 4 | oxford
# Processing Record 38 of Set 4 | omaruru
# Processing Record 39 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 4 | omboue
# Processing Record 41 of Set 4 | lebu
# Processing Record 42 of Set 4 | greenwood
# Processing Record 43 of Set 4 | sao joao da barra
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | puro
# Processing Record 46 of Set 4 | boende
# Processing Record 47 of Set 4 | norman wells
# Processing Record 48 of Set 4 | cidreira
# Processing Record 49 of Set 4 | vwawa
# Processing Record 50 of Set 4 | rio claro
# Processing Record 1 of Set 5 | telimele
# Processing Record 2 of Set 5 | cherskiy
# Processing Record 3 of Set 5 | codrington
# Processing Record 4 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 5 | boyolangu
# Processing Record 7 of Set 5 | hofn
# Processing Record 8 of Set 5 | nishihara
# Processing Record 9 of Set 5 | ravar
# Processing Record 10 of Set 5 | mehamn
# Processing Record 11 of Set 5 | tilichiki
# Processing Record 12 of Set 5 | broome
# Processing Record 13 of Set 5 | atar
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | coari
# Processing Record 16 of Set 5 | taksimo
# Processing Record 17 of Set 5 | wangaratta
# Processing Record 18 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 5 | casper
# Processing Record 20 of Set 5 | ketchikan
# Processing Record 21 of Set 5 | faya
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | lubumbashi
# Processing Record 24 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 5 | san patricio
# Processing Record 26 of Set 5 | sandy bay
# Processing Record 27 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 5 | moyale
# Processing Record 29 of Set 5 | viedma
# Processing Record 30 of Set 5 | segezha
# Processing Record 31 of Set 5 | katsuura
# Processing Record 32 of Set 5 | panormos
# Processing Record 33 of Set 5 | goroka
# Processing Record 34 of Set 5 | luderitz
# Processing Record 35 of Set 5 | kipini
# Processing Record 36 of Set 5 | bulgan
# Processing Record 37 of Set 5 | whitehorse
# Processing Record 38 of Set 5 | penzance
# Processing Record 39 of Set 5 | general roca
# Processing Record 40 of Set 5 | hilo
# Processing Record 41 of Set 5 | tommot
# Processing Record 42 of Set 5 | sur
# Processing Record 43 of Set 5 | saint george
# Processing Record 44 of Set 5 | nanyamba
# Processing Record 45 of Set 5 | manokwari
# Processing Record 46 of Set 5 | tecoanapa
# Processing Record 47 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 48 of Set 5 | termoli
# Processing Record 49 of Set 5 | san borja
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 6 | nanortalik
# Processing Record 2 of Set 6 | issoire
# Processing Record 3 of Set 6 | vallenar
# Processing Record 4 of Set 6 | taoudenni
# Processing Record 5 of Set 6 | yian
# City not found. Skipping...
# Processing Record 6 of Set 6 | baiyin
# Processing Record 7 of Set 6 | puerto lopez
# Processing Record 8 of Set 6 | gigmoto
# Processing Record 9 of Set 6 | charters towers
# Processing Record 10 of Set 6 | ponta do sol
# Processing Record 11 of Set 6 | hayden
# Processing Record 12 of Set 6 | ambovombe
# Processing Record 13 of Set 6 | valparaiso
# Processing Record 14 of Set 6 | aubenas
# Processing Record 15 of Set 6 | jimma
# Processing Record 16 of Set 6 | marawi
# Processing Record 17 of Set 6 | yar-sale
# Processing Record 18 of Set 6 | naze
# Processing Record 19 of Set 6 | itarema
# Processing Record 20 of Set 6 | maceio
# Processing Record 21 of Set 6 | derzhavinsk
# Processing Record 22 of Set 6 | oussouye
# Processing Record 23 of Set 6 | ban nahin
# Processing Record 24 of Set 6 | bonthe
# Processing Record 25 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 6 | tazovskiy
# Processing Record 27 of Set 6 | stornoway
# Processing Record 28 of Set 6 | grand-santi
# Processing Record 29 of Set 6 | ostrovnoy
# Processing Record 30 of Set 6 | smithers
# Processing Record 31 of Set 6 | dubbo
# Processing Record 32 of Set 6 | lagoa
# Processing Record 33 of Set 6 | le port
# Processing Record 34 of Set 6 | sosnovo-ozerskoye
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | anamur
# Processing Record 37 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 6 | canon city
# Processing Record 39 of Set 6 | namatanai
# Processing Record 40 of Set 6 | champerico
# Processing Record 41 of Set 6 | baykit
# Processing Record 42 of Set 6 | rovaniemi
# Processing Record 43 of Set 6 | bambous virieux
# Processing Record 44 of Set 6 | makinsk
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | tateyama
# Processing Record 47 of Set 6 | carutapera
# Processing Record 48 of Set 6 | victoria
# Processing Record 49 of Set 6 | pangai
# Processing Record 50 of Set 6 | miri
# Processing Record 1 of Set 7 | chara
# Processing Record 2 of Set 7 | dingli
# Processing Record 3 of Set 7 | port blair
# Processing Record 4 of Set 7 | marienburg
# Processing Record 5 of Set 7 | kapit
# Processing Record 6 of Set 7 | tasiilaq
# Processing Record 7 of Set 7 | zhangye
# Processing Record 8 of Set 7 | ochamchira
# Processing Record 9 of Set 7 | sibolga
# Processing Record 10 of Set 7 | charleston
# Processing Record 11 of Set 7 | grasse
# Processing Record 12 of Set 7 | dalvik
# Processing Record 13 of Set 7 | vardo
# Processing Record 14 of Set 7 | wanning
# Processing Record 15 of Set 7 | ust-kulom
# Processing Record 16 of Set 7 | portland
# Processing Record 17 of Set 7 | moron
# Processing Record 18 of Set 7 | minab
# Processing Record 19 of Set 7 | russkaya polyana
# Processing Record 20 of Set 7 | tungor
# Processing Record 21 of Set 7 | san carlos de bariloche
# Processing Record 22 of Set 7 | moses lake
# Processing Record 23 of Set 7 | dandong
# Processing Record 24 of Set 7 | kieta
# Processing Record 25 of Set 7 | osmena
# Processing Record 26 of Set 7 | kasempa
# Processing Record 27 of Set 7 | tahe
# Processing Record 28 of Set 7 | roald
# Processing Record 29 of Set 7 | dutse
# Processing Record 30 of Set 7 | saldanha
# Processing Record 31 of Set 7 | uthal
# Processing Record 32 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 7 | natal
# Processing Record 34 of Set 7 | bathsheba
# Processing Record 35 of Set 7 | kahului
# Processing Record 36 of Set 7 | bilma
# Processing Record 37 of Set 7 | vanimo
# Processing Record 38 of Set 7 | havoysund
# Processing Record 39 of Set 7 | chake chake
# Processing Record 40 of Set 7 | orlik
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | yumen
# Processing Record 43 of Set 7 | peniche
# Processing Record 44 of Set 7 | tenenkou
# Processing Record 45 of Set 7 | lukovo
# Processing Record 46 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | daru
# Processing Record 50 of Set 7 | snyder
# Processing Record 1 of Set 8 | nemuro
# Processing Record 2 of Set 8 | klyuchi
# Processing Record 3 of Set 8 | dhidhdhoo
# Processing Record 4 of Set 8 | chapais
# Processing Record 5 of Set 8 | porto novo
# Processing Record 6 of Set 8 | kondopoga
# Processing Record 7 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 8 | aitape
# Processing Record 9 of Set 8 | mekhe
# Processing Record 10 of Set 8 | vitim
# Processing Record 11 of Set 8 | san jose
# Processing Record 12 of Set 8 | jadu
# Processing Record 13 of Set 8 | mmathubudukwane
# Processing Record 14 of Set 8 | rio gallegos
# Processing Record 15 of Set 8 | nabire
# Processing Record 16 of Set 8 | alofi
# Processing Record 17 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 8 | qaqortoq
# Processing Record 19 of Set 8 | denpasar
# Processing Record 20 of Set 8 | bonavista
# Processing Record 21 of Set 8 | lata
# Processing Record 22 of Set 8 | lavrentiya
# Processing Record 23 of Set 8 | teguldet
# Processing Record 24 of Set 8 | obluche
# City not found. Skipping...
# Processing Record 25 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 8 | afanasyevo
# City not found. Skipping...
# Processing Record 27 of Set 8 | joshimath
# Processing Record 28 of Set 8 | muncar
# Processing Record 29 of Set 8 | vysokogornyy
# Processing Record 30 of Set 8 | murray bridge
# Processing Record 31 of Set 8 | san quintin
# Processing Record 32 of Set 8 | paita
# Processing Record 33 of Set 8 | kismayo
# Processing Record 34 of Set 8 | sogne
# Processing Record 35 of Set 8 | dalhousie
# Processing Record 36 of Set 8 | egvekinot
# Processing Record 37 of Set 8 | anloga
# Processing Record 38 of Set 8 | cockburn town
# Processing Record 39 of Set 8 | canakkale
# Processing Record 40 of Set 8 | muros
# Processing Record 41 of Set 8 | birjand
# Processing Record 42 of Set 8 | lima
# Processing Record 43 of Set 8 | la palma
# Processing Record 44 of Set 8 | inuvik
# Processing Record 45 of Set 8 | cotonou
# Processing Record 46 of Set 8 | agudos
# Processing Record 47 of Set 8 | manzil salim
# Processing Record 48 of Set 8 | ukiah
# Processing Record 49 of Set 8 | oranjemund
# Processing Record 50 of Set 8 | berlevag
# Processing Record 1 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 9 | kutum
# Processing Record 3 of Set 9 | maldonado
# Processing Record 4 of Set 9 | moville
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | college
# Processing Record 7 of Set 9 | itoman
# Processing Record 8 of Set 9 | narasannapeta
# Processing Record 9 of Set 9 | olafsvik
# Processing Record 10 of Set 9 | shache
# Processing Record 11 of Set 9 | husavik
# Processing Record 12 of Set 9 | ust-tsilma
# Processing Record 13 of Set 9 | bowen
# Processing Record 14 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 9 | tapes
# Processing Record 16 of Set 9 | shenjiamen
# Processing Record 17 of Set 9 | yerbogachen
# Processing Record 18 of Set 9 | aksarka
# Processing Record 19 of Set 9 | ler
# Processing Record 20 of Set 9 | garowe
# Processing Record 21 of Set 9 | torbay
# Processing Record 22 of Set 9 | praia da vitoria
# Processing Record 23 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 9 | antsohihy
# Processing Record 25 of Set 9 | shellbrook
# Processing Record 26 of Set 9 | hangu
# Processing Record 27 of Set 9 | avera
# Processing Record 28 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 9 | wajima
# Processing Record 30 of Set 9 | olavarria
# Processing Record 31 of Set 9 | santa rosa
# Processing Record 32 of Set 9 | plettenberg bay
# Processing Record 33 of Set 9 | villa carlos paz
# Processing Record 34 of Set 9 | pitea
# Processing Record 35 of Set 9 | bilibino
# Processing Record 36 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 37 of Set 9 | uvat
# Processing Record 38 of Set 9 | noumea
# Processing Record 39 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 9 | camopi
# Processing Record 41 of Set 9 | vahan
# Processing Record 42 of Set 9 | opaka
# Processing Record 43 of Set 9 | vagur
# Processing Record 44 of Set 9 | ternate
# Processing Record 45 of Set 9 | cabo rojo
# Processing Record 46 of Set 9 | tevaitoa
# Processing Record 47 of Set 9 | constantine
# Processing Record 48 of Set 9 | batagay
# Processing Record 49 of Set 9 | yanam
# Processing Record 50 of Set 9 | douala
# Processing Record 1 of Set 10 | bogande
# Processing Record 2 of Set 10 | vao
# Processing Record 3 of Set 10 | hollins
# Processing Record 4 of Set 10 | saskylakh
# Processing Record 5 of Set 10 | half moon bay
# Processing Record 6 of Set 10 | dali
# Processing Record 7 of Set 10 | iqaluit
# Processing Record 8 of Set 10 | batemans bay
# Processing Record 9 of Set 10 | abalak
# Processing Record 10 of Set 10 | ushtobe
# Processing Record 11 of Set 10 | caravelas
# Processing Record 12 of Set 10 | nova ushytsya
# Processing Record 13 of Set 10 | rocha
# Processing Record 14 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 10 | tual
# Processing Record 16 of Set 10 | teknaf
# Processing Record 17 of Set 10 | tutoia
# Processing Record 18 of Set 10 | huaihua
# Processing Record 19 of Set 10 | trelew
# Processing Record 20 of Set 10 | banda aceh
# Processing Record 21 of Set 10 | salta
# Processing Record 22 of Set 10 | jardim
# Processing Record 23 of Set 10 | cayenne
# Processing Record 24 of Set 10 | ibra
# Processing Record 25 of Set 10 | katherine
# Processing Record 26 of Set 10 | houma
# Processing Record 27 of Set 10 | chunoyar
# Processing Record 28 of Set 10 | bid
# City not found. Skipping...
# Processing Record 29 of Set 10 | micheweni
# Processing Record 30 of Set 10 | the pas
# Processing Record 31 of Set 10 | vila
# Processing Record 32 of Set 10 | airai
# Processing Record 33 of Set 10 | zhuhai
# Processing Record 34 of Set 10 | mpika
# Processing Record 35 of Set 10 | hailar
# Processing Record 36 of Set 10 | taltal
# Processing Record 37 of Set 10 | buala
# Processing Record 38 of Set 10 | eydhafushi
# Processing Record 39 of Set 10 | liverpool
# Processing Record 40 of Set 10 | landau
# Processing Record 41 of Set 10 | gizo
# Processing Record 42 of Set 10 | oga
# Processing Record 43 of Set 10 | alice
# Processing Record 44 of Set 10 | karratha
# Processing Record 45 of Set 10 | barmer
# Processing Record 46 of Set 10 | timra
# Processing Record 47 of Set 10 | windhoek
# Processing Record 48 of Set 10 | birin
# Processing Record 49 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 50 of Set 10 | teya
# Processing Record 1 of Set 11 | kota kinabalu
# Processing Record 2 of Set 11 | dzerzhinsk
# Processing Record 3 of Set 11 | devils lake
# Processing Record 4 of Set 11 | crotone
# Processing Record 5 of Set 11 | ayabaca
# Processing Record 6 of Set 11 | opuwo
# Processing Record 7 of Set 11 | port hedland
# Processing Record 8 of Set 11 | la ronge
# Processing Record 9 of Set 11 | umm kaddadah
# Processing Record 10 of Set 11 | achalpur
# Processing Record 11 of Set 11 | praia
# Processing Record 12 of Set 11 | gombong
# Processing Record 13 of Set 11 | tucuman
# Processing Record 14 of Set 11 | umea
# Processing Record 15 of Set 11 | nuevo imperial
# Processing Record 16 of Set 11 | shelburne
# Processing Record 17 of Set 11 | siyana
# Processing Record 18 of Set 11 | launceston
# Processing Record 19 of Set 11 | westport
# Processing Record 20 of Set 11 | harper
# Processing Record 21 of Set 11 | guinsiliban
# City not found. Skipping...
# Processing Record 22 of Set 11 | kazanskaya
# Processing Record 23 of Set 11 | abyek
# Processing Record 24 of Set 11 | kudahuvadhoo
# Processing Record 25 of Set 11 | ondjiva
# Processing Record 26 of Set 11 | mackay
# Processing Record 27 of Set 11 | kulhudhuffushi
# Processing Record 28 of Set 11 | bahia de caraquez
# Processing Record 29 of Set 11 | tacuati
# Processing Record 30 of Set 11 | mrakovo
# Processing Record 31 of Set 11 | douentza
# Processing Record 32 of Set 11 | kavaratti
# Processing Record 33 of Set 11 | batagay-alyta
# Processing Record 34 of Set 11 | sigli
# Processing Record 35 of Set 11 | port hawkesbury
# Processing Record 36 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 11 | heihe
# Processing Record 38 of Set 11 | strelka
# Processing Record 39 of Set 11 | myitkyina
# Processing Record 40 of Set 11 | sinnamary
# Processing Record 41 of Set 11 | general bravo
# Processing Record 42 of Set 11 | jiupu
# Processing Record 43 of Set 11 | mbandaka
# Processing Record 44 of Set 11 | ambilobe
# Processing Record 45 of Set 11 | ogulin
# Processing Record 46 of Set 11 | ishinomaki
# Processing Record 47 of Set 11 | cururupu
# Processing Record 48 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 11 | sawtell
# Processing Record 50 of Set 11 | lundazi
# Processing Record 1 of Set 12 | koson
# Processing Record 2 of Set 12 | erzin
# Processing Record 3 of Set 12 | ramhormoz
# Processing Record 4 of Set 12 | peleduy
# Processing Record 5 of Set 12 | kharp
# Processing Record 6 of Set 12 | ca mau
# Processing Record 7 of Set 12 | shitkino
# Processing Record 8 of Set 12 | pochutla
# Processing Record 9 of Set 12 | freetown
# Processing Record 10 of Set 12 | janikowo
# Processing Record 11 of Set 12 | oyugis
# Processing Record 12 of Set 12 | santa maria
# Processing Record 13 of Set 12 | san rafael
# Processing Record 14 of Set 12 | veraval
# Processing Record 15 of Set 12 | longyearbyen
# Processing Record 16 of Set 12 | hornepayne
# Processing Record 17 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 12 | grand gaube
# Processing Record 19 of Set 12 | duz
# City not found. Skipping...
# Processing Record 20 of Set 12 | wynyard
# Processing Record 21 of Set 12 | srednekolymsk
# Processing Record 22 of Set 12 | toktogul
# Processing Record 23 of Set 12 | tofield
# Processing Record 24 of Set 12 | yatsuo
# Processing Record 25 of Set 12 | turukhansk
# Processing Record 26 of Set 12 | tuatapere
# Processing Record 27 of Set 12 | lazurne
# Processing Record 28 of Set 12 | can tho
# Processing Record 29 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 30 of Set 12 | eldorado
# Processing Record 31 of Set 12 | aleksandrovsk-sakhalinskiy
# Processing Record 32 of Set 12 | atambua
# Processing Record 33 of Set 12 | korla
# Processing Record 34 of Set 12 | raudeberg
# Processing Record 35 of Set 12 | qinzhou
# Processing Record 36 of Set 12 | gushikawa
# Processing Record 37 of Set 12 | burgeo
# Processing Record 38 of Set 12 | nome
# Processing Record 39 of Set 12 | ballina
# Processing Record 40 of Set 12 | cavalcante
# Processing Record 41 of Set 12 | roebourne
# Processing Record 42 of Set 12 | copiapo
# Processing Record 43 of Set 12 | bima
# Processing Record 44 of Set 12 | purranque
# Processing Record 45 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 12 | abu samrah
# Processing Record 47 of Set 12 | alta floresta
# Processing Record 48 of Set 12 | chateauroux
# Processing Record 49 of Set 12 | sao jose da coroa grande
# Processing Record 50 of Set 12 | aripuana
# Processing Record 1 of Set 13 | tonj
# Processing Record 2 of Set 13 | sukumo
# Processing Record 3 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 4 of Set 13 | quatre cocos
# Processing Record 5 of Set 13 | rabo de peixe
# Processing Record 6 of Set 13 | prambanan
# City not found. Skipping...
# Processing Record 7 of Set 13 | colquechaca
# Processing Record 8 of Set 13 | palm springs
# Processing Record 9 of Set 13 | bay roberts
# Processing Record 10 of Set 13 | west bay
# Processing Record 11 of Set 13 | corridonia
# Processing Record 12 of Set 13 | nouadhibou
# Processing Record 13 of Set 13 | port hardy
# Processing Record 14 of Set 13 | meadow lake
# Processing Record 15 of Set 13 | shuangyang
# Processing Record 16 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 17 of Set 13 | turbat
# Processing Record 18 of Set 13 | dunedin
# Processing Record 19 of Set 13 | lompoc
# Processing Record 20 of Set 13 | svetlogorsk
# Processing Record 21 of Set 13 | youghal
# Processing Record 22 of Set 13 | dwarka
# Processing Record 23 of Set 13 | pacific grove
# Processing Record 24 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 13 | aswan
# Processing Record 26 of Set 13 | walvis bay
# Processing Record 27 of Set 13 | caruray
# Processing Record 28 of Set 13 | maple creek
# Processing Record 29 of Set 13 | vila franca do campo
# Processing Record 30 of Set 13 | cooma
# Processing Record 31 of Set 13 | puerto carreno
# Processing Record 32 of Set 13 | capreol
# Processing Record 33 of Set 13 | nuuk
# Processing Record 34 of Set 13 | tiznit
# Processing Record 35 of Set 13 | gornopravdinsk
# Processing Record 36 of Set 13 | kamenicky senov
# Processing Record 37 of Set 13 | high level
# Processing Record 38 of Set 13 | yangambi
# Processing Record 39 of Set 13 | paamiut
# Processing Record 40 of Set 13 | canutama
# Processing Record 41 of Set 13 | ahuimanu
# Processing Record 42 of Set 13 | anadyr
# Processing Record 43 of Set 13 | labuhan
# Processing Record 44 of Set 13 | los llanos de aridane
# Processing Record 45 of Set 13 | igarka
# Processing Record 46 of Set 13 | cuauhtemoc
# Processing Record 47 of Set 13 | lasa
# Processing Record 48 of Set 13 | vakhtan
# Processing Record 49 of Set 13 | arlit
# Processing Record 50 of Set 13 | ponta delgada
# Processing Record 1 of Set 14 | nichinan
# Processing Record 2 of Set 14 | nanning
# Processing Record 3 of Set 14 | japura
# Processing Record 4 of Set 14 | esmeraldas
# Processing Record 5 of Set 14 | inhambane
# Processing Record 6 of Set 14 | maracana
# Processing Record 7 of Set 14 | bend
# Processing Record 8 of Set 14 | cadiz
# Processing Record 9 of Set 14 | poum
# Processing Record 10 of Set 14 | hobyo
# Processing Record 11 of Set 14 | nantucket
# Processing Record 12 of Set 14 | necochea
# Processing Record 13 of Set 14 | akdepe
# Processing Record 14 of Set 14 | linxia
# Processing Record 15 of Set 14 | buy
# Processing Record 16 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 14 | santa isabel do rio negro
# Processing Record 19 of Set 14 | bandarbeyla
# Processing Record 20 of Set 14 | hapao
# Processing Record 21 of Set 14 | saiha
# Processing Record 22 of Set 14 | maragogi
# Processing Record 23 of Set 14 | sangar
# Processing Record 24 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 25 of Set 14 | hasaki
# Processing Record 26 of Set 14 | hellendoorn
# Processing Record 27 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 28 of Set 14 | umm lajj
# Processing Record 29 of Set 14 | mount isa
# Processing Record 30 of Set 14 | azare
# Processing Record 31 of Set 14 | kalach-na-donu
# Processing Record 32 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 14 | maniitsoq
# Processing Record 34 of Set 14 | acapulco
# Processing Record 35 of Set 14 | padang
# Processing Record 36 of Set 14 | troitsko-pechorsk
# Processing Record 37 of Set 14 | bayanday
# Processing Record 38 of Set 14 | hurghada
# Processing Record 39 of Set 14 | jalu
# Processing Record 40 of Set 14 | road town
# Processing Record 41 of Set 14 | kiruna
# Processing Record 42 of Set 14 | krasnoarmeysk
# Processing Record 43 of Set 14 | aykhal
# Processing Record 44 of Set 14 | ambad
# Processing Record 45 of Set 14 | trairi
# Processing Record 46 of Set 14 | bantry
# Processing Record 47 of Set 14 | am timan
# Processing Record 48 of Set 14 | manta
# Processing Record 49 of Set 14 | doba
# Processing Record 50 of Set 14 | dauriya
# Processing Record 1 of Set 15 | makakilo city
# Processing Record 2 of Set 15 | severodvinsk
# Processing Record 3 of Set 15 | mashhad
# Processing Record 4 of Set 15 | santa teresa
# Processing Record 5 of Set 15 | bull savanna
# Processing Record 6 of Set 15 | taguatinga
# Processing Record 7 of Set 15 | arroyos y esteros
# Processing Record 8 of Set 15 | troitskoye
# Processing Record 9 of Set 15 | yilan
# Processing Record 10 of Set 15 | vung tau
# Processing Record 11 of Set 15 | okhotsk
# Processing Record 12 of Set 15 | kenai
# Processing Record 13 of Set 15 | yeppoon
# Processing Record 14 of Set 15 | pierrelatte
# Processing Record 15 of Set 15 | wenling
# Processing Record 16 of Set 15 | comodoro rivadavia
# Processing Record 17 of Set 15 | fallon
# Processing Record 18 of Set 15 | bubaque
# Processing Record 19 of Set 15 | inirida
# Processing Record 20 of Set 15 | locri
# Processing Record 21 of Set 15 | oriximina
# Processing Record 22 of Set 15 | elizabeth city
# Processing Record 23 of Set 15 | cap malheureux
# Processing Record 24 of Set 15 | kolokani
# Processing Record 25 of Set 15 | evensk
# Processing Record 26 of Set 15 | lishu
# Processing Record 27 of Set 15 | rawson
# Processing Record 28 of Set 15 | catuday
# Processing Record 29 of Set 15 | apozol
# Processing Record 30 of Set 15 | east angus
# Processing Record 31 of Set 15 | havelock
# Processing Record 32 of Set 15 | tariba
# Processing Record 33 of Set 15 | gomel
# Processing Record 34 of Set 15 | vakhrushev
# Processing Record 35 of Set 15 | portmore
# Processing Record 36 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 15 | san jeronimo
# Processing Record 38 of Set 15 | emirdag
# Processing Record 39 of Set 15 | tansen
# Processing Record 40 of Set 15 | guerrero negro
# Processing Record 41 of Set 15 | ahipara
# Processing Record 42 of Set 15 | bismarck
# Processing Record 43 of Set 15 | dicabisagan
# Processing Record 44 of Set 15 | palmer
# Processing Record 45 of Set 15 | mugumu
# Processing Record 46 of Set 15 | ziro
# Processing Record 47 of Set 15 | vestmanna
# Processing Record 48 of Set 15 | lethem
# Processing Record 49 of Set 15 | pakxan
# Processing Record 50 of Set 15 | cochrane
# Processing Record 1 of Set 16 | elban
# Processing Record 2 of Set 16 | saint-leu
# Processing Record 3 of Set 16 | jimenez
# Processing Record 4 of Set 16 | hudson bay
# Processing Record 5 of Set 16 | bozova
# Processing Record 6 of Set 16 | saint-augustin
# Processing Record 7 of Set 16 | ho chi minh city
# Processing Record 8 of Set 16 | paytug
# City not found. Skipping...
# Processing Record 9 of Set 16 | huron
# Processing Record 10 of Set 16 | astana
# Processing Record 11 of Set 16 | sinop
# Processing Record 12 of Set 16 | danjiangkou
# Processing Record 13 of Set 16 | koutiala
# Processing Record 14 of Set 16 | sundsvall
# Processing Record 15 of Set 16 | dauphin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng   Current Description  Max Temp  Humidity  \
# 0      Cape Town -33.9258   18.4232            few clouds     70.09        64
# 1        Talnakh  69.4865   88.3972            light snow     18.14        94
# 2        Isangel -19.5500  169.2667      scattered clouds     76.08        88
# 3     Filadelfia  39.9523  -75.1638            few clouds     56.55        55
# 4         Castro -24.7911  -50.0119  heavy intensity rain     77.38        60
# 5  Florianopolis -27.6146  -48.5012            light rain     81.41        61
# 6       Coquimbo -29.9533  -71.3436         broken clouds     58.73        82
# 7        Kurchum  48.5722   83.6542             clear sky     33.76        52
# 8        Te Anau -45.4167  167.7167            light rain     50.34        90
# 9        Ushuaia -54.8000  -68.3000            light rain     42.42        87
#
#    Cloudiness  Wind Speed Country
# 0          20       18.41      ZA
# 1         100        9.37      RU
# 2          46        3.11      VU
# 3          20       10.36      US
# 4         100        8.32      BR
# 5          20       14.97      BR
# 6          75        8.05      CL
# 7           5        6.85      KZ
# 8          69        5.79      NZ
# 9         100       21.85      AR

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Current Description', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
newcolumnorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[newcolumnorder]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cape Town      ZA -33.9258   18.4232     70.09        64          20
# 1        Talnakh      RU  69.4865   88.3972     18.14        94         100
# 2        Isangel      VU -19.5500  169.2667     76.08        88          46
# 3     Filadelfia      US  39.9523  -75.1638     56.55        55          20
# 4         Castro      BR -24.7911  -50.0119     77.38        60         100
# 5  Florianopolis      BR -27.6146  -48.5012     81.41        61          20
# 6       Coquimbo      CL -29.9533  -71.3436     58.73        82          75
# 7        Kurchum      KZ  48.5722   83.6542     33.76        52           5
# 8        Te Anau      NZ -45.4167  167.7167     50.34        90          69
# 9        Ushuaia      AR -54.8000  -68.3000     42.42        87         100
#
#    Wind Speed   Current Description
# 0       18.41            few clouds
# 1        9.37            light snow
# 2        3.11      scattered clouds
# 3       10.36            few clouds
# 4        8.32  heavy intensity rain
# 5       14.97            light rain
# 6        8.05         broken clouds
# 7        6.85             clear sky
# 8        5.79            light rain
# 9       21.85            light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
